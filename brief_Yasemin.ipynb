# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

data = pd.read_csv('Data/Billionaires Statistics Dataset.csv')
data.head(2)
# Out:
#    rank  finalWorth          category                personName   age  \
# 0     1      211000  Fashion & Retail  Bernard Arnault & family  74.0
# 1     2      180000        Automotive                 Elon Musk  51.0
#
#          country    city         source        industries  \
# 0         France   Paris           LVMH  Fashion & Retail
# 1  United States  Austin  Tesla, SpaceX        Automotive
#
#   countryOfCitizenship  ... cpi_change_country           gdp_country  \
# 0               France  ...                1.1   $2,715,518,274,227
# 1        United States  ...                7.5  $21,427,700,000,000
#
#   gross_tertiary_education_enrollment  \
# 0                                65.6
# 1                                88.2
#
#   gross_primary_education_enrollment_country life_expectancy_country  \
# 0                                      102.5                    82.5
# 1                                      101.8                    78.5
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2640 entries, 0 to 2639
# Data columns (total 35 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   rank                                        2640 non-null   int64
#  1   finalWorth                                  2640 non-null   int64
#  2   category                                    2640 non-null   object
#  3   personName                                  2640 non-null   object
#  4   age                                         2575 non-null   float64
#  5   country                                     2602 non-null   object
#  6   city                                        2568 non-null   object
#  7   source                                      2640 non-null   object
#  8   industries                                  2640 non-null   object
#  9   countryOfCitizenship                        2640 non-null   object
# ...

# %%
top_countries = data["country"].value_counts().head(10)
top_countries
# Out:
# country
# United States     754
# China             523
# India             157
# Germany           102
# United Kingdom     82
# Russia             79
# Switzerland        78
# Hong Kong          68
# Italy              55
# Singapore          46
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 4))

top_countries.plot(kind='bar', color = "purple")
plt.xlabel("Pays")
plt.ylabel("Nombre de milliardaires")
plt.title("Top 10 des Pays avec le plus de Milliardaires")
plt.xticks(rotation=75)

plt.show()

# %%
df = pd.DataFrame(data)

# Utilisez pandas pour transformer le DataFrame en un format adapté pour le graphique
df_melted = df.melt('country', var_name='gender', value_name='count')

# Créez le graphique catplot avec deux barres pour chaque pays
sns.catplot(x='country', y='count', hue='gender', kind='bar', data=df_melted, height=6, aspect=2)

# Ajoutez un titre et des étiquettes d'axe
plt.title('Proportion d\'hommes et de femmes par pays')
plt.xlabel('Pays')
plt.ylabel('Nombre de milliardaires')

# Affichez le graphique
plt.show()
